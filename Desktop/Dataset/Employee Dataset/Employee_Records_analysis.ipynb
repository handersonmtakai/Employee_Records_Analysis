# %%
print("Jupyter is working inside VS Code")
# Out:
# Jupyter is working inside VS Code

# %%
print("Jupyter is now working perfectly")
# Out:
# Jupyter is now working perfectly

# %%
import pandas as pd

# %%
import os
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'analysis.ipynb', 'hotel_bookings.csv', 'python-projects', 'sharedStorage', 'Untitled.ipynb']

# %%
import pandas as pd

df = pd.read_csv('hotel_bookings.csv')
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df.shape
df.info()
df.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  str
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  str
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df.shape
# Out:
# (119390, 32)

# %%
import pandas as pd

df = pd.read_csv('hotel_bookings.csv')
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
import pandas as pd

df = pd.read_csv('employee_records.csv')
df
# Out:
#        Employee_ID    Employee_Name  Age    Country   Department    Position  \
# 0                1    Daniel Taylor   25         UK           HR     Analyst
# 1                2      Ethan Brown   44      India    Marketing   Executive
# 2                3  Sophia Martinez   51      Japan      Finance   Developer
# 3                4   Ethan Martinez   47    Germany      Support     Analyst
# 4                5        Mia Brown   32  Australia      Support  Consultant
# ...            ...              ...  ...        ...          ...         ...
# 29995        29996        Mia Brown   42  Australia      Support     Manager
# 29996        29997     Mason Thomas   41     Mexico  Engineering   Assistant
# 29997        29998    Lily Anderson   44      India    Marketing   Developer
# 29998        29999     Mason Taylor   46     Brazil      Finance   Assistant
# 29999        30000    Lucas Jackson   30     Mexico      Finance   Developer
#
# ...

# %%
import pandas as pd

df = pd.read_csv('employee_records.csv')
df.head()
# Out:
#    Employee_ID    Employee_Name  Age    Country Department    Position  \
# 0            1    Daniel Taylor   25         UK         HR     Analyst
# 1            2      Ethan Brown   44      India  Marketing   Executive
# 2            3  Sophia Martinez   51      Japan    Finance   Developer
# 3            4   Ethan Martinez   47    Germany    Support     Analyst
# 4            5        Mia Brown   32  Australia    Support  Consultant
#
#        Salary   Bonus  Tax Rate % Joining_Date
# 0  142,278.32  10,000        0.15   06/04/2023
# 1   98,549.20   5,000        0.15    1/13/2018
# 2   85,565.84   5,000        0.10    4/30/2015
# 3   34,513.67   2,000        0.10    6/17/2015
# 4   45,339.72   2,000        0.05    2/22/2019

# %%
df.shape
# Out:
# (30000, 10)

# %%
df.info()
df.describe
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Employee_ID    30000 non-null  int64
#  1   Employee_Name  30000 non-null  str
#  2   Age            30000 non-null  int64
#  3   Country        30000 non-null  str
#  4   Department     30000 non-null  str
#  5   Position       30000 non-null  str
#  6   Salary         30000 non-null  str
#  7   Bonus          30000 non-null  str
#  8   Tax Rate %     30000 non-null  float64
#  9   Joining_Date   30000 non-null  str
# dtypes: float64(1), int64(2), str(7)
# memory usage: 2.3 MB
# <bound method NDFrame.describe of        Employee_ID    Employee_Name  Age    Country   Department    Position  \
# 0                1    Daniel Taylor   25         UK           HR     Analyst
# 1                2      Ethan Brown   44      India    Marketing   Executive
# ...

# %%
print(df["Salary"].dtype)
# Out:
# str

# %%
df["Bonus"]= df["Bonus"].str.replace(",", "")
df["Bonus"]= df["Bonus"].astype(float)

df["Salary"] = df["Salary"].str.replace(",", "")
df["Salary"] = df["Salary"].astype(float)

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Employee_ID    30000 non-null  int64
#  1   Employee_Name  30000 non-null  str
#  2   Age            30000 non-null  int64
#  3   Country        30000 non-null  str
#  4   Department     30000 non-null  str
#  5   Position       30000 non-null  str
#  6   Salary         30000 non-null  float64
#  7   Bonus          30000 non-null  float64
#  8   Tax Rate %     30000 non-null  float64
#  9   Joining_Date   30000 non-null  str
# dtypes: float64(3), int64(2), str(5)
# memory usage: 2.3 MB
# None

# %%
print(df["Joining_Date"].head(30))
# Out:
# 0     06/04/2023
# 1      1/13/2018
# 2      4/30/2015
# 3      6/17/2015
# 4      2/22/2019
# 5      9/29/2018
# 6      8/24/2021
# 7     01/08/2021
# 8     12/20/2018
# 9      5/18/2018
# 10     8/22/2024
# 11    11/20/2016
# 12    07/03/2024
# 13    11/12/2017
# 14    09/07/2021
# 15    10/11/2021
# 16    08/10/2016
# 17     2/20/2017
# 18    12/04/2021
# 19    03/01/2021
# 20     8/24/2022
# 21    10/25/2021
# 22    11/09/2018
# 23     4/16/2022
# 24    01/09/2021
# 25     4/25/2015
# 26    05/12/2024
# 27     7/21/2024
# 28    11/04/2016
# 29    08/03/2022
# Name: Joining_Date, dtype: str

# %%
df["Joining_Date"] =pd.to_datetime(df["Joining_Date"])

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Employee_ID    30000 non-null  int64
#  1   Employee_Name  30000 non-null  str
#  2   Age            30000 non-null  int64
#  3   Country        30000 non-null  str
#  4   Department     30000 non-null  str
#  5   Position       30000 non-null  str
#  6   Salary         30000 non-null  float64
#  7   Bonus          30000 non-null  float64
#  8   Tax Rate %     30000 non-null  float64
#  9   Joining_Date   30000 non-null  datetime64[us]
# dtypes: datetime64[us](1), float64(3), int64(2), str(4)
# memory usage: 2.3 MB
# None

# %%
import pandas as pd
df = pd.read_csv("employee_records.csv")

# %%
df.head()
# Out:
#    Employee_ID    Employee_Name  Age    Country Department    Position  \
# 0            1    Daniel Taylor   25         UK         HR     Analyst
# 1            2      Ethan Brown   44      India  Marketing   Executive
# 2            3  Sophia Martinez   51      Japan    Finance   Developer
# 3            4   Ethan Martinez   47    Germany    Support     Analyst
# 4            5        Mia Brown   32  Australia    Support  Consultant
#
#        Salary   Bonus  Tax Rate % Joining_Date
# 0  142,278.32  10,000        0.15   06/04/2023
# 1   98,549.20   5,000        0.15    1/13/2018
# 2   85,565.84   5,000        0.10    4/30/2015
# 3   34,513.67   2,000        0.10    6/17/2015
# 4   45,339.72   2,000        0.05    2/22/2019

# %%
df.isnull().sum()
# Out:
# Employee_ID      0
# Employee_Name    0
# Age              0
# Country          0
# Department       0
# Position         0
# Salary           0
# Bonus            0
# Tax Rate %       0
# Joining_Date     0
# dtype: int64

# %%
df["Department"].value_counts()
# Out:
# Department
# Engineering    5070
# Sales          5019
# Marketing      5007
# Support        4990
# HR             4976
# Finance        4938
# Name: count, dtype: int64

# %%
df["Position"].value_counts()
# Out:
# Position
# Executive     5124
# Consultant    5022
# Analyst       5008
# Developer     4988
# Assistant     4934
# Manager       4924
# Name: count, dtype: int64

# %%
df["Country"].value_counts()
# Out:
# Country
# Germany      3090
# Australia    3052
# UK           3021
# France       3010
# Mexico       2991
# India        2985
# Canada       2969
# USA          2967
# Brazil       2961
# Japan        2954
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#         Employee_ID           Age    Tax Rate %
# count  30000.000000  30000.000000  30000.000000
# mean   15000.500000     40.978067      0.112292
# std     8660.398374     11.234432      0.036038
# min        1.000000     22.000000      0.050000
# 25%     7500.750000     31.000000      0.100000
# 50%    15000.500000     41.000000      0.100000
# 75%    22500.250000     51.000000      0.150000
# max    30000.000000     60.000000      0.150000

# %%
pip install sqlalchemy pymysql
# Out:
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.5/2.1 MB 1.1 MB/s eta 0:00:02
#    -------------- ------------------------- 0.8/2.1 MB 1.1 MB/s eta 0:00:02
#    ------------------- -------------------- 1.0/2.1 MB 1.2 MB/s eta 0:00:01
#    ------------------------ --------------- 1.3/2.1 MB 1.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.6/2.1 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.8/2.1 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.8/2.1 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 1.0 MB/s  0:00:02
# ...
#
#    ---------------------------------------- 0/3 [pymysql]
# ...

# %%
from sqlalchemy import create_engine

# %%
import pymysql

# %%
from sqlalchemy import create_engine
engine = create_engine(
"mysql+pymysql://root:Mtakaison96#@localhost/hr_analytics")
print("Connection ready")
# Out:
# Connection ready

# %%
engine.connect()
print("MySQL connection successful")
# Out:
# MySQL connection successful

# %%
df.to_sql(
    name= "employee_records",
    con=engine,
    if_exists="replace",
    index=False
)
print("upload complete")
# Out:
# upload complete

# %%
import pandas as pd
df = pd.read_csv("employee_records.csv")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Employee_ID    30000 non-null  int64
#  1   Employee_Name  30000 non-null  str
#  2   Age            30000 non-null  int64
#  3   Country        30000 non-null  str
#  4   Department     30000 non-null  str
#  5   Position       30000 non-null  str
#  6   Salary         30000 non-null  str
#  7   Bonus          30000 non-null  str
#  8   Tax Rate %     30000 non-null  float64
#  9   Joining_Date   30000 non-null  str
# dtypes: float64(1), int64(2), str(7)
# memory usage: 2.3 MB

# %%
df.shape
# Out:
# (30000, 10)

# %%
df["Bonus"]= df["Bonus"].str.replace(",", "")
df["Bonus"]= df["Bonus"].astype(float)

df["Salary"] = df["Salary"].str.replace(",", "")
df["Salary"] = df["Salary"].astype(float)

df["Joining_Date"] =pd.to_datetime(df["Joining_Date"])

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Employee_ID    30000 non-null  int64
#  1   Employee_Name  30000 non-null  str
#  2   Age            30000 non-null  int64
#  3   Country        30000 non-null  str
#  4   Department     30000 non-null  str
#  5   Position       30000 non-null  str
#  6   Salary         30000 non-null  float64
#  7   Bonus          30000 non-null  float64
#  8   Tax Rate %     30000 non-null  float64
#  9   Joining_Date   30000 non-null  datetime64[us]
# dtypes: datetime64[us](1), float64(3), int64(2), str(4)
# memory usage: 2.3 MB

# %%
from sqlalchemy import create_engine
engine = create_engine(
"mysql+pymysql://root:Mtakaison96#@localhost/hr_analytics")

# %%
engine.connect()
print("MySQL connection successful")
# Out:
# MySQL connection successful

# %%
df.to_sql(
    name= "employee_records",
    con=engine,
    if_exists="replace",
    index=False
)
print("upload complete")
# Out:
# upload complete

# %%
df[["Salary", "Bonus"]].dtypes
# Out:
# Salary    float64
# Bonus     float64
# dtype: object
